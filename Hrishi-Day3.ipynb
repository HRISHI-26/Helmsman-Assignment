# %%
username = 'Hrishinandan'
password = '8743'
otp = '375'
name = input("Enter your name ")
userPassword = input("Enter your password ")
userotp = input("Enter the otp ")
if name == username :
  if userPassword == password :
      if userotp == otp :
         print("Welcome You are In !!! Mr " + username)
      else :
        print("Incorrect OTP")
  else :
    print("Password Incorrect")
else :
  print("There is no such user")
# Out:
# Enter your name Hrishinandan
# Enter your password 8743
# Enter the otp 375
# Welcome You are In !!! Mr Hrishinandan

# %%
marks = int(input("Enter your marks"))
if marks > 85:
  print("Woww you have got a 'Distinction'")
elif marks < 70:
  print("Sorry you are failed!!!")
elif 85>marks>70:
  print("You are passed")
# Out:
# Enter your marks94
# Woww you have got a 'Distinction'

# %%
Studentmarks = [50,66,44,88,46,51,99,77,62,9,]
for h in Studentmarks :
  if h > 50 :
   print(h)
# Out:
# 66
# 88
# 51
# 99
# 77
# 62
