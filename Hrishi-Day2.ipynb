# %%
6+26
# Out:
# 32

# %%
55-44
# Out:
# 11

# %%
100*100
# Out:
# 10000

# %%
1000/50
# Out:
# 20.0

# %%
int(input("enter anumber "))
# Out:
# enter anumber 6
# 6

# %%
int(input("Enter a number")) * 10
# Out:
# Enter a number6
# 60

# %%
int(input("enter a number")) / 10
# Out:
# enter a number70
# 7.0

# %%
float(input("Enter a number")) * 4
# Out:
# Enter a number6.4
# 25.6

# %%
float(input("Enter a number")) / 4
# Out:
# Enter a number25.6
# 6.4

# %%
a = 10
b = 3
print(a*b)
print(a/b)
print(a+b)
print(a-b)
# Out:
# 30
# 3.3333333333333335
# 13
# 7
