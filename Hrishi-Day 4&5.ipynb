# %%
import pandas as pd

# %%
from google.colab import files

uploaded = files.upload()

print (uploaded)
# Out:
#      <input type="file" id="files-a918fe95-2985-404b-a795-ea80352cc6eb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a918fe95-2985-404b-a795-ea80352cc6eb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving StudentsPerformance.csv to StudentsPerformance.csv
# ...

# %%
# !ls
# Out:
# sample_data  StudentsPerformance.csv

# %%
import pandas as pd

# %%
student = pd.read_csv("StudentsPerformance.csv")
student.head()
# Out:
#    gender race/ethnicity  ... reading score writing score
# 0  female        group B  ...            72            74
# 1  female        group C  ...            90            88
# 2  female        group B  ...            95            93
# 3    male        group A  ...            57            44
# 4    male        group C  ...            78            75
#
# [5 rows x 8 columns]

# %%
student.plot.scatter( "math score","writing score", figsize=(10,3))

# %%
student.plot.scatter("parental level of education","writing score", figsize=(10,3))

# %%
student.plot.scatter("reading score","writing score", figsize=(10,3))

# %% [markdown]
# From the above graphs we can understand that parentel level of education,math score and reading score have a positive corelation with writing score
