# %%
import pandas as pd

# %%
import numpy as np

# %%
from google.colab import files

upload = files.upload()
# Out:
#      <input type="file" id="files-a069c1cb-00b9-40fa-8b16-862b8f95cce2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a069c1cb-00b9-40fa-8b16-862b8f95cce2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving StudentsPerformance.csv to StudentsPerformance.csv

# %%
student = pd.read_csv("StudentsPerformance.csv")
student.head()
# Out:
#    gender race/ethnicity  ... reading score writing score
# 0  female        group B  ...            72            74
# 1  female        group C  ...            90            88
# 2  female        group B  ...            95            93
# 3    male        group A  ...            57            44
# 4    male        group C  ...            78            75
#
# [5 rows x 8 columns]

# %%
= np.array(student.iloc[:,[6]].values)
reascr=np.array(student.iloc[:,[6]].values)
print("wriscr",wriscr [:6])
print("reascr",reascr [:6])
# Out:
# wriscr [[72]
#  [90]
#  [95]
#  [57]
#  [78]
#  [83]]
# reascr [[72]
#  [90]
#  [95]
#  [57]
#  [78]
#  [83]]

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit( wriscr,reascr )
model.score(wriscr,reascr )
# Out:
# 1.0

# %%
import matplotlib.pyplot as plt
plt.scatter( wriscr,reascr )
print(wriscr.shape )
plt.plot( wriscr , model.predict( wriscr.reshape(-1,1)),'y')
# Out:
# (1000, 1)
